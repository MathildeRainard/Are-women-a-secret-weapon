# %%
#First import all the libraries we will be using for analysis:
import numpy as np
import pandas as pd
import scipy.stats as stats
from pathlib import Path
from pandas.api.types import CategoricalDtype
#and for plotting graphs:
import matplotlib.pyplot as plt
import seaborn as sns
#and set up the figure parameters
plt.rcParams['figure.figsize'] = [12, 7]
sns.set()
sns.set_style("whitegrid")
sns.set_palette("bright")

# %%
# Import the database into a dataframe
data_file =('PERFECT-Diss-Data.xlsx')
df_Gender_Climate = pd.read_excel(data_file, index_col=0)

# %%
df_Gender_Climate['GGI 2020'].replace(to_replace=[999], value=np.nan, inplace=True)
df_Gender_Climate['EPI 2020'].replace(to_replace=[999], value=np.nan, inplace=True)
df_Gender_Climate['GII 2019'].replace(to_replace=[999], value=np.nan, inplace=True)
df_Gender_Climate['CCH EPI 2020'].replace(to_replace=[999], value=np.nan, inplace=True)
df_Gender_Climate['GHP EPI 2020'].replace(to_replace=[999], value=np.nan, inplace=True)
df_Gender_Climate['GIB EPI 2020'].replace(to_replace=[999], value=np.nan, inplace=True)
df_Gender_Climate['GGIE 2020'].replace(to_replace=[999], value=np.nan, inplace=True)
df_Gender_Climate['GGIEA 2020'].replace(to_replace=[999], value=np.nan, inplace=True)
df_Gender_Climate['GGIH 2020'].replace(to_replace=[999], value=np.nan, inplace=True)
df_Gender_Climate['GGIP 2020'].replace(to_replace=[999], value=np.nan, inplace=True)

# %%
df_Gender_nonans = df_Gender_Climate.dropna()

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
rp_GGI = stats.pearsonr(df_Gender_nonans['GGI 2020'], df_Gender_nonans['EPI 2020'])
rp_GII = stats.pearsonr(df_Gender_nonans['GII 2019'], df_Gender_nonans['EPI 2020'])

sns.regplot(ax=ax[0], data=df_Gender_nonans, x='EPI 2020', y='GGI 2020', color = 'blue')
ax[0].set_ylabel('GGGI')
ax[0].set_xlabel('EPI')
ax[0].set_title('(a) Correlations between GGGI and EPI')
ax[0].text(0.6, 0.2, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GGI[0],rp_GGI[1]), transform=ax[0].transAxes)

sns.regplot(ax=ax[1], data=df_Gender_nonans, x='EPI 2020', y='GII 2019', color = 'green') 
ax[1].set_ylabel('GII')
ax[1].set_xlabel('EPI')
ax[1].set_title('(b) Correlations between GII and EPI')
ax[1].text(0.6, 0.8, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GII[0],rp_GII[1]), transform=ax[1].transAxes)

plt.savefig('H1_graph')

# %%
stats.pearsonr(df_Gender_nonans['GGI 2020'], df_Gender_nonans['EPI 2020'])
# Out:
# (0.5227912766057629, 1.2977901399763404e-11)

# %%
stats.pearsonr(df_Gender_nonans['GGI 2020'], df_Gender_nonans['GIB EPI 2020'])
# Out:
# (0.13302746715530295, 0.10944710304626747)

# %%
stats.pearsonr(df_Gender_nonans['GII 2019'], df_Gender_nonans['EPI 2020'])
# Out:
# (-0.8682704614621787, 1.1046739762811228e-45)

# %%
fig, ax = plt.subplots(1, 3, figsize=(16, 4))
rp_GGICC = stats.pearsonr(df_Gender_nonans['GGI 2020'], df_Gender_nonans['CCH EPI 2020'])
rp_GGIGHP = stats.pearsonr(df_Gender_nonans['GGI 2020'], df_Gender_nonans['GHP EPI 2020'])
rp_GGIGIB = stats.pearsonr(df_Gender_nonans['GGI 2020'], df_Gender_nonans['GIB EPI 2020'])

sns.regplot(ax=ax[0], data=df_Gender_nonans, x='CCH EPI 2020', y='GGI 2020', color = 'blue')
ax[0].set_ylabel('GGGI')
ax[0].set_xlabel('Climate Change')
ax[0].set_title('(a) Correlations between GGGI and EPI-CC')
ax[0].text(0.6, 0.1, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GGICC[0],rp_GGICC[1]), transform=ax[0].transAxes)

sns.regplot(ax=ax[1], data=df_Gender_nonans, x='GHP EPI 2020', y='GGI 2020', color = 'blue') 
ax[1].set_ylabel('GGGI')
ax[1].set_xlabel('GHG emissions')
ax[1].set_title('(b) Correlations between GGGI and EPI-GHG')
ax[1].text(0.6, 0.8, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GGIGHP[0],rp_GGIGHP[1]), transform=ax[1].transAxes)

sns.scatterplot(ax=ax[2], data=df_Gender_nonans, x='GIB EPI 2020', y='GGI 2020', color = 'blue') 
ax[2].set_ylabel('GGGI')
ax[2].set_xlabel('GHG GDP intensity')
ax[2].set_title('(c) Correlations between GGGI and EPI-GHG-GDP')
ax[2].text(0.2, 0.8, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GGIGIB[0],rp_GGIGIB[1]), transform=ax[2].transAxes)

plt.savefig('H3_graph1')

# %%
fig, ax = plt.subplots(1, 3, figsize=(16, 4))
rp_GIICC = stats.pearsonr(df_Gender_nonans['GII 2019'], df_Gender_nonans['CCH EPI 2020'])
rp_GIIGHP = stats.pearsonr(df_Gender_nonans['GII 2019'], df_Gender_nonans['GHP EPI 2020'])
rp_GIIGIB = stats.pearsonr(df_Gender_nonans['GII 2019'], df_Gender_nonans['GIB EPI 2020'])

sns.regplot(ax=ax[0], data=df_Gender_nonans, x='CCH EPI 2020', y='GII 2019', color = 'green')
ax[0].set_ylabel('GII')
ax[0].set_xlabel('Climate Change')
ax[0].set_title('(d) Correlations between GII and EPI-CC')
ax[0].text(0.6, 0.8, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GIIGHP[0],rp_GIIGHP[1]), transform=ax[0].transAxes)

sns.regplot(ax=ax[1], data=df_Gender_nonans, x='GHP EPI 2020', y='GII 2019', color = 'green') 
ax[1].set_ylabel('GII')
ax[1].set_xlabel('GHG emissions')
ax[1].set_title('(e) Correlations between GII and EPI-GHG')
ax[1].text(0.1, 0.8, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GIIGHP[0],rp_GIIGHP[1]), transform=ax[1].transAxes)

sns.scatterplot(ax=ax[2], data=df_Gender_nonans, x='GIB EPI 2020', y='GII 2019', color = 'green') 
ax[2].set_ylabel('GII')
ax[2].set_xlabel('GHG GDP intensity')
ax[2].set_title('(f) Correlations between GII and EPI-GHG-GDP')
ax[2].text(0.6, 0.8, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GIIGHP[0],rp_GIIGHP[1]), transform=ax[2].transAxes)

plt.savefig('H3_graph2')

# %%
stats.pearsonr(df_Gender_nonans['GII 2019'], df_Gender_nonans['GIB EPI 2020'])
# Out:
# (-0.054326784916998896, 0.514871025314419)

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
rp_GGIE = stats.pearsonr(df_Gender_nonans['GGIE 2020'], df_Gender_nonans['EPI 2020'])
rp_GGIP = stats.pearsonr(df_Gender_nonans['GGIP 2020'], df_Gender_nonans['EPI 2020'])

sns.regplot(ax=ax[0], data=df_Gender_nonans, x='EPI 2020', y='GGIE 2020', color = 'blue')
ax[0].set_ylabel('GGGI Economic opportunities')
ax[0].set_xlabel('EPI')
ax[0].set_title('(a) Correlations between GGGI Economic and EPI')
ax[0].text(0.6, 0.2, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GGIE[0],rp_GGIP[1]), transform=ax[0].transAxes)


sns.regplot(ax=ax[1], data=df_Gender_nonans, x='EPI 2020', y='GGIP 2020', color = 'blue') 
ax[1].set_ylabel('GGGI Political empowerment')
ax[1].set_xlabel('EPI')
ax[1].set_title('(b) Correlations between GGGI Politic and EPI')
ax[1].text(0.6, 0.8, "Pearson R = {:.2f}\np = {:.2f}".format(rp_GGIP[0],rp_GGIP[1]), transform=ax[1].transAxes)
plt.savefig('H4_graph')

# %%
stats.pearsonr(df_Gender_nonans['GGIE 2020'], df_Gender_nonans['EPI 2020'])
# Out:
# (0.2679408712486381, 0.001076572498603398)

# %%
stats.pearsonr(df_Gender_nonans['GGIP 2020'], df_Gender_nonans['EPI 2020'])
# Out:
# (0.39059901766230987, 1.0930406209738957e-06)

# %%
stats.pearsonr(df_Gender_nonans['GGIE 2020'], df_Gender_nonans['CCH EPI 2020'])
# Out:
# (0.20275193998035435, 0.014113928690819491)

# %%
stats.pearsonr(df_Gender_nonans['GGIE 2020'], df_Gender_nonans['GHP EPI 2020'])
# Out:
# (-0.13145696645216584, 0.11373656940132297)

# %%
stats.pearsonr(df_Gender_nonans['GGIE 2020'], df_Gender_nonans['GIB EPI 2020'])
# Out:
# (-0.01723437141649828, 0.8364245276680882)

# %%
stats.pearsonr(df_Gender_nonans['GGIP 2020'], df_Gender_nonans['CCH EPI 2020'])
# Out:
# (0.36066973365867877, 7.74959946371298e-06)

# %%
stats.pearsonr(df_Gender_nonans['GGIP 2020'], df_Gender_nonans['GHP EPI 2020'])
# Out:
# (-0.09584672104865827, 0.2498074174788849)

# %%
stats.pearsonr(df_Gender_nonans['GGIP 2020'], df_Gender_nonans['GIB EPI 2020'])
# Out:
# (0.20167000190993756, 0.014647590744548555)

# %%
stats.pearsonr(df_Gender_nonans['GGI 2020'], df_Gender_nonans['GIB EPI 2020'])
# Out:
# (0.13302746715530295, 0.10944710304626747)

# %%
stats.pearsonr(df_Gender_nonans['GGI 2020'], df_Gender_nonans['CCH EPI 2020'])
# Out:
# (0.46754579966826704, 2.6856265838080707e-09)

# %%
stats.pearsonr(df_Gender_nonans['GGI 2020'], df_Gender_nonans['GHP EPI 2020'])
# Out:
# (-0.2665302551681244, 0.0011465846115874356)

# %%
stats.pearsonr(df_Gender_nonans['GII 2019'], df_Gender_nonans['CCH EPI 2020'])
# Out:
# (-0.6949103973421578, 2.260919836894979e-22)

# %%
stats.pearsonr(df_Gender_nonans['GII 2019'], df_Gender_nonans['GHP EPI 2020'])
# Out:
# (0.7494864909082853, 1.4136942333473707e-27)
